# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import requests
import csv
from datetime import date, timedelta

# %%
# Gather data from the last 3 seasons (2022-2025 NCAA seasons) and compile into a CSV for easier access and further data manipulation
def daterange(start_date, end_date):
    for n in range((end_date - start_date).days + 1):
        yield start_date + timedelta(n)

def fetch_games_for_date(date_obj):
    date_str = date_obj.strftime('%Y%m%d')
    url = (
        'https://site.api.espn.com/apis/site/v2/'
        'sports/basketball/mens-college-basketball/scoreboard'
        f'?dates={date_str}'
    )
    resp = requests.get(url)
    resp.raise_for_status()
    data = resp.json()
    games = []
    for event in data.get('events', []):
        comp = event.get('competitions', [{}])[0]
        teams = comp.get('competitors', [])
        if len(teams) != 2:
            continue
        away = next(t for t in teams if t.get('homeAway') == 'away')
        home = next(t for t in teams if t.get('homeAway') == 'home')
        games.append({
            'date': date_obj.isoformat(),
            'away_team': away['team']['displayName'],
            'home_team': home['team']['displayName'],
            'away_score': away.get('score'),
            'home_score': home.get('score'),
            'arena': comp.get('venue', {}).get('fullName')
        })
    return games

# Fetch and save games for the past 3 seasons only (Nov → Apr)
from datetime import date

# Define exact season windows
season_ranges = [
    (date(2022, 11, 1), date(2023, 4, 15)),
    (date(2023, 11, 1), date(2024, 4, 15)),
    (date(2024, 11, 1), date(2025, 4, 15)),
]

all_games = []
for start_date, end_date in season_ranges:
    for single_date in daterange(start_date, end_date):
        daily = fetch_games_for_date(single_date)
        all_games.extend(daily)
        if daily:
            print(f"  – {len(daily)} games on {single_date}")

# Write CSV
with open('ncaa_mbb_games_past3seasons.csv', 'w', newline='', encoding='utf-8') as f:
    writer = csv.DictWriter(
        f,
        fieldnames=[
            'date', 'away_team', 'home_team',
            'away_score', 'home_score', 'arena'
        ]
    )
    writer.writeheader()
    writer.writerows(all_games)

print(f"Saved {len(all_games)} games to ncaa_mbb_games_past3seasons.csv")
# Out:
#   – 24 games on 2022-11-07
#   – 10 games on 2022-11-08
#   – 26 games on 2022-11-09
#   – 5 games on 2022-11-10
#   – 16 games on 2022-11-11
#   – 59 games on 2022-11-12
#   – 1 games on 2022-11-13
#   – 7 games on 2022-11-14
#   – 6 games on 2022-11-15
#   – 3 games on 2022-11-16
#   – 3 games on 2022-11-17
#   – 5 games on 2022-11-18
#   – 1 games on 2022-11-19
#   – 5 games on 2022-11-20
#   – 1 games on 2022-11-21
#   – 69 games on 2022-11-22
#   – 3 games on 2022-11-23
#   – 22 games on 2022-11-24
#   – 3 games on 2022-11-25
#   – 1 games on 2022-11-26
#   – 2 games on 2022-11-27
#   – 2 games on 2022-11-28
#   – 3 games on 2022-11-29
#   – 2 games on 2022-11-30
#   – 2 games on 2022-12-01
#   – 4 games on 2022-12-02
#   – 6 games on 2022-12-03
#   – 7 games on 2022-12-04
#   – 2 games on 2022-12-05
#   – 6 games on 2022-12-06
#   – 4 games on 2022-12-07
#   – 2 games on 2022-12-08
#   – 1 games on 2022-12-09
#   – 11 games on 2022-12-10
#   – 2 games on 2022-12-11
#   – 2 games on 2022-12-12
#   – 3 games on 2022-12-13
#   – 3 games on 2022-12-14
#   – 1 games on 2022-12-15
#   – 18 games on 2022-12-16
#   – 9 games on 2022-12-17
#   – 2 games on 2022-12-18
#   – 38 games on 2022-12-19
#   – 9 games on 2022-12-20
#   – 11 games on 2022-12-21
#                           arena
# 0          Dean E. Smith Center
# 1     McCarthey Athletic Center
# 2               Fertitta Center
# 3                    Rupp Arena
# 4                Ferrell Center
# ...                         ...
# 3086          Lucas Oil Stadium
# 3087           State Farm Arena
# 3088                  Alamodome
# 3089                  Alamodome
# 3090                  Alamodome
#
# [3091 rows x 6 columns]

# %%
import numpy as np
# Take 25 random games to ensure randomness and nonbiased results, extract frames out of these games only 
rows_to_idx = np.random.randin
rows_to_idx= np.random.randint(0, 3090, 25)
rows_to_idx
# Out:
# array([3014, 1750, 1263, 1290, 2319,  910,  423, 3041,  279,  706, 2858,
#        2414, 1460,  639,  527,  304, 1066, 2012, 2629,  893, 1517,  956,
#        1622,  758, 2334])

# %%
print(ncaa_games.iloc[3014])
print('---------------------')
print(ncaa_games.iloc[1750])
print('---------------------')
print(ncaa_games.iloc[1263])
print('---------------------')
print(ncaa_games.iloc[1290])
print('---------------------')
print(ncaa_games.iloc[2319])
print('---------------------')
print(ncaa_games.iloc[910])
print('---------------------')
print(ncaa_games.iloc[423])
print('---------------------')
print(ncaa_games.iloc[3041])
print('---------------------')
print(ncaa_games.iloc[279])
print('---------------------')
print(ncaa_games.iloc[706])
print('---------------------')
print(ncaa_games.iloc[2858])
print('---------------------')
print(ncaa_games.iloc[2414])
print('---------------------')
print(ncaa_games.iloc[1460])
print('---------------------')
print(ncaa_games.iloc[639])
print('---------------------')
print(ncaa_games.iloc[527])
print('---------------------')
print(ncaa_games.iloc[304])
print('---------------------')
print(ncaa_games.iloc[1066])
print('---------------------')
print(ncaa_games.iloc[2012])
print('---------------------')
print(ncaa_games.iloc[2629])
print('---------------------')
print(ncaa_games.iloc[893])
print('---------------------')
print(ncaa_games.iloc[1517])
print('---------------------')
print(ncaa_games.iloc[956])
print('---------------------')
print(ncaa_games.iloc[1622])
print('---------------------')
print(ncaa_games.iloc[758])
print('---------------------')
print(ncaa_games.iloc[2334])
print('---------------------')
# Out:
# date                2025-03-15
# away_team     Arizona Wildcats
# home_team      Houston Cougars
# away_score                  64
# home_score                  72
# arena          T-Mobile Center
# Name: 3014, dtype: object
# ---------------------
# date                   2024-01-31
# away_team     Boise State Broncos
# home_team        New Mexico Lobos
# away_score                     86
# home_score                     78
# arena                     The Pit
# Name: 1750, dtype: object
# ---------------------
# date                    2023-11-17
# away_team             Mercer Bears
# home_team     Alabama Crimson Tide
# away_score                      67
# home_score                      98
# arena             Coleman Coliseum
# Name: 1263, dtype: object
# ---------------------
# date                    2023-11-22
# away_team     Tennessee Volunteers
# home_team          Kansas Jayhawks
# away_score                      60
# home_score                      69
# arena          Stan Sheriff Center
# Name: 1290, dtype: object
# ---------------------
# date                     2024-12-02
# away_team      William & Mary Tribe
# home_team     Old Dominion Monarchs
# away_score                       83
# home_score                       88
# arena                Chartway Arena
# Name: 2319, dtype: object
# ---------------------
# date                      2023-03-04
# away_team            Wyoming Cowboys
# home_team     San Diego State Aztecs
# away_score                        50
# home_score                        67
# arena                   Viejas Arena
# Name: 910, dtype: object
# ---------------------
# date                      2022-12-22
# away_team         Morgan State Bears
# home_team           Arizona Wildcats
# away_score                        68
# home_score                        93
# arena         McKale Memorial Center
# Name: 423, dtype: object
# ---------------------
# date                 2025-03-20
# away_team     Utah State Aggies
# home_team           UCLA Bruins
# away_score                   47
# home_score                   72
# arena                Rupp Arena
# Name: 3041, dtype: object
# ---------------------
# date                      2022-12-01
# away_team           Arizona Wildcats
# home_team                  Utah Utes
# away_score                        66
# home_score                        81
# arena         Jon M. Huntsman Center
# Name: 279, dtype: object
# ---------------------
# date                   2023-02-04
# away_team        Miami Hurricanes
# home_team          Clemson Tigers
# away_score                     78
# home_score                     74
# arena         Littlejohn Coliseum
# Name: 706, dtype: object
# ---------------------
# date                 2025-02-15
# away_team       Missouri Tigers
# home_team      Georgia Bulldogs
# away_score                   87
# home_score                   74
# arena         Stegeman Coliseum
# Name: 2858, dtype: object
# ---------------------
# date                              2024-12-16
# away_team     West Virginia Wesleyan Bobcats
# home_team           Marshall Thundering Herd
# away_score                                63
# home_score                                93
# arena                   Cam Henderson Center
# Name: 2414, dtype: object
# ---------------------
# date                                  2023-12-18
# away_team     Bluefield University Ramblin' Rams
# home_team               Marshall Thundering Herd
# away_score                                    70
# home_score                                   103
# arena                       Cam Henderson Center
# Name: 1460, dtype: object
# ---------------------
# date                    2023-01-23
# away_team         New Mexico Lobos
# home_team         Nevada Wolf Pack
# away_score                      94
# home_score                      97
# arena         Lawlor Events Center
# Name: 639, dtype: object
# ---------------------
# date                             2023-01-09
# away_team     East-West University Phantoms
# home_team             Chicago State Cougars
# away_score                               70
# home_score                               90
# arena              Jones Convocation Center
# Name: 527, dtype: object
# ---------------------
# date                  2022-12-06
# away_team     Maryland Terrapins
# home_team      Wisconsin Badgers
# away_score                    59
# home_score                    64
# arena                Kohl Center
# Name: 304, dtype: object
# ---------------------
# date                   2023-03-10
# away_team     Arkansas Razorbacks
# home_team        Texas A&M Aggies
# away_score                     61
# home_score                     67
# arena           Bridgestone Arena
# Name: 1066, dtype: object
# ---------------------
# date                2024-03-14
# away_team          USC Trojans
# home_team     Arizona Wildcats
# away_score                  49
# home_score                  70
# arena           T-Mobile Arena
# Name: 2012, dtype: object
# ---------------------
# date                          2025-01-15
# away_team     West Virginia Mountaineers
# home_team                Houston Cougars
# away_score                            54
# home_score                            70
# arena                    Fertitta Center
# Name: 2629, dtype: object
# ---------------------
# date                      2023-03-03
# away_team         Grand Canyon Lopes
# home_team     Utah Tech Trailblazers
# away_score                        71
# home_score                        61
# arena                    Burns Arena
# Name: 893, dtype: object
# ---------------------
# date                       2023-12-29
# away_team            Arizona Wildcats
# home_team     California Golden Bears
# away_score                        100
# home_score                         81
# arena                   Haas Pavilion
# Name: 1517, dtype: object
# ---------------------
# date                     2023-03-07
# away_team      Weber State Wildcats
# home_team     Montana State Bobcats
# away_score                       58
# home_score                       60
# arena           Idaho Central Arena
# Name: 956, dtype: object
# ---------------------
# date                        2024-01-12
# away_team              Stetson Hatters
# home_team     Queens University Royals
# away_score                          84
# home_score                          66
# arena                      Curry Arena
# Name: 1622, dtype: object
# ---------------------
# date                       2023-02-15
# away_team           Xavier Musketeers
# home_team     Marquette Golden Eagles
# away_score                         68
# home_score                         69
# arena                    Fiserv Forum
# Name: 758, dtype: object
# ---------------------
# date                   2024-12-03
# away_team       Kentucky Wildcats
# home_team          Clemson Tigers
# away_score                     66
# home_score                     70
# arena         Littlejohn Coliseum
# Name: 2334, dtype: object
# ---------------------
